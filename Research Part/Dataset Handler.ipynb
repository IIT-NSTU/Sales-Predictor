# %%
import pandas as pd
import math

# %% [markdown]
# These data were collected manually from a retail electronic shop named "Samir Electronics", located in Madhabpur, Habiganj. Which is a distributor of a renowed electronic brand in Bangladesh named "Walton".
# First step is converting the raw csv files to a proper dataset.
#
# These csv files represents data for an individual year and contains columns as "Date", "Amount", "Model No1", "Model No2", "Model No3", and so on.

# %%
# Reading individual csv files and converting to dataframes.

yearlySales1 = pd.read_csv('dataset/Project Dataset/2022_23.csv')
yearlySales2 = pd.read_csv('dataset/Project Dataset/2023_24.csv')

# %%
# Concating all dataframes together to a single dataframe.

salesData = pd.concat([yearlySales1, yearlySales2]).reset_index(drop=True)

# %%
# Checking which columns do not have any sales data.

emptyColumns = []
for i in salesData.columns:
    if i != "Date" and salesData[i].sum() == 0:
        emptyColumns.append(i)

print(emptyColumns)
# Out:
# ['Padestal Fan', 'Wash', 'Beverage Cooler', '1B6']

# %%
# Removing unnecessary emtpy columns.

salesData = salesData.drop(columns = emptyColumns)
print(salesData.columns)
# Out:
# Index(['Date', 'Amount', 'Multiplug', 'Mobile P16', 'Mobile N5', 'Mobile H10',
#        'Speaker', 'Light Bulb', 'Weight Scale', 'Tornedo Fan',
#        ...
#        '3J0GDEL DD', '5F3GDEL', '5F3GDEL-DD', 'Air Cooler', '18 A AC',
#        '18 C AC', '12 C AC', '24 B AC', '24 C AC', '18 F AC'],
#       dtype='object', length=125)

# %%
for column in salesData.columns:
    print(f"Descriptive statistics for {column}:")
    print(salesData[column].describe())
    print("\n")
# Out:
# Descriptive statistics for Date:
# count           761
# unique          761
# top       14/4/2022
# freq              1
# Name: Date, dtype: object
#
#
# Descriptive statistics for Amount:
# count    7.600000e+02
# mean     1.584120e+05
# std      1.450694e+05
# min      0.000000e+00
# 25%      7.137500e+04
# 50%      1.304000e+05
# 75%      2.052250e+05
# max      1.110200e+06
# Name: Amount, dtype: float64
#
#
# Descriptive statistics for Multiplug:
# count    28.000000
# mean      1.035714
# std       0.188982
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: Multiplug, dtype: float64
#
#
# Descriptive statistics for Mobile P16:
# count    35.000000
# mean      1.057143
# std       0.235504
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: Mobile P16, dtype: float64
#
#
# Descriptive statistics for Mobile N5:
# count    11.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: Mobile N5, dtype: float64
#
#
# Descriptive statistics for Mobile H10:
# count    4.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: Mobile H10, dtype: float64
#
#
# Descriptive statistics for Speaker:
# count    4.00
# mean     1.25
# std      0.50
# min      1.00
# 25%      1.00
# 50%      1.00
# 75%      1.25
# max      2.00
# Name: Speaker, dtype: float64
#
#
# Descriptive statistics for Light Bulb:
# count    8.000000
# mean     1.250000
# std      0.707107
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      3.000000
# Name: Light Bulb, dtype: float64
#
#
# Descriptive statistics for Weight Scale:
# count    12.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: Weight Scale, dtype: float64
#
#
# Descriptive statistics for Tornedo Fan:
# count    12.000000
# mean      1.250000
# std       0.452267
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.250000
# max       2.000000
# Name: Tornedo Fan, dtype: float64
#
#
# Descriptive statistics for 12 inch Fan:
# count    70.000000
# mean      1.542857
# std       1.002688
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       7.000000
# Name: 12 inch Fan, dtype: float64
#
#
# Descriptive statistics for 14 inch Fan:
# count    159.000000
# mean       2.308176
# std        2.289076
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max       14.000000
# Name: 14 inch Fan, dtype: float64
#
#
# Descriptive statistics for 17 inch Fan:
# count    265.00000
# mean       3.69434
# std        5.00993
# min        1.00000
# 25%        1.00000
# 50%        2.00000
# 75%        4.00000
# max       38.00000
# Name: 17 inch Fan, dtype: float64
#
#
# Descriptive statistics for Stand Fan:
# count    88.000000
# mean      1.352273
# std       0.695466
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       4.000000
# Name: Stand Fan, dtype: float64
#
#
# Descriptive statistics for Ceiling Fan:
# count    110.000000
# mean       1.663636
# std        1.454366
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       10.000000
# Name: Ceiling Fan, dtype: float64
#
#
# Descriptive statistics for Wall Move:
# count    30.000000
# mean      1.166667
# std       0.461133
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: Wall Move, dtype: float64
#
#
# Descriptive statistics for Water Filter:
# count    9.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: Water Filter, dtype: float64
#
#
# Descriptive statistics for Glyser:
# count    28.000000
# mean      1.357143
# std       0.731021
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.250000
# max       4.000000
# Name: Glyser, dtype: float64
#
#
# Descriptive statistics for Gas Stove:
# count    170.000000
# mean       1.200000
# std        0.601773
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        7.000000
# Name: Gas Stove, dtype: float64
#
#
# Descriptive statistics for Fry Pan:
# count    58.000000
# mean      1.189655
# std       0.511513
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: Fry Pan, dtype: float64
#
#
# Descriptive statistics for Oven:
# count    38.000000
# mean      1.052632
# std       0.226294
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: Oven, dtype: float64
#
#
# Descriptive statistics for Ruti Tawa:
# count    17.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: Ruti Tawa, dtype: float64
#
#
# Descriptive statistics for Kettle:
# count    201.000000
# mean       1.442786
# std        0.853206
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        7.000000
# Name: Kettle, dtype: float64
#
#
# Descriptive statistics for Iron:
# count    174.000000
# mean       1.327586
# std        0.664229
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: Iron, dtype: float64
#
#
# Descriptive statistics for Induction Cooker:
# count    16.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: Induction Cooker, dtype: float64
#
#
# Descriptive statistics for Infered Cooker:
# count    63.000000
# mean      1.269841
# std       0.544958
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: Infered Cooker, dtype: float64
#
#
# Descriptive statistics for Multi Cooker:
# count    22.000000
# mean      1.136364
# std       0.351250
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: Multi Cooker, dtype: float64
#
#
# Descriptive statistics for Pressure Cooker:
# count    56.000000
# mean      1.071429
# std       0.259870
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: Pressure Cooker, dtype: float64
#
#
# Descriptive statistics for Rice Cooker:
# count    203.000000
# mean       1.359606
# std        0.684875
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000
# Name: Rice Cooker, dtype: float64
#
#
# Descriptive statistics for Blender:
# count    76.000000
# mean      1.131579
# std       0.442481
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: Blender, dtype: float64
#
#
# Descriptive statistics for Grinder:
# count    210.000000
# mean       1.304762
# std        0.620600
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: Grinder, dtype: float64
#
#
# Descriptive statistics for Washing Machine:
# count    57.000000
# mean      1.017544
# std       0.132453
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: Washing Machine, dtype: float64
#
#
# Descriptive statistics for Room Heater:
# count    37.000000
# mean      1.621622
# std       0.923500
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       4.000000
# Name: Room Heater, dtype: float64
#
#
# Descriptive statistics for Remote:
# count    46.000000
# mean      1.065217
# std       0.326747
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: Remote, dtype: float64
#
#
# Descriptive statistics for 24 inch LED:
# count    106.000000
# mean       1.198113
# std        0.559248
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        5.000000
# Name: 24 inch LED, dtype: float64
#
#
# Descriptive statistics for 32 inch LED:
# count    235.000000
# mean       1.319149
# std        0.623828
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: 32 inch LED, dtype: float64
#
#
# Descriptive statistics for 40 inch LED:
# count    43.000000
# mean      1.023256
# std       0.152499
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 40 inch LED, dtype: float64
#
#
# Descriptive statistics for 43 inch 4K:
# count    67.000000
# mean      1.089552
# std       0.287694
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 43 inch 4K, dtype: float64
#
#
# Descriptive statistics for Stabilizer:
# count    21.000000
# mean      1.142857
# std       0.358569
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: Stabilizer, dtype: float64
#
#
# Descriptive statistics for Protector:
# count    27.000000
# mean      1.148148
# std       0.456045
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: Protector, dtype: float64
#
#
# Descriptive statistics for 1X1RXXX:
# count    9.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 1X1RXXX, dtype: float64
#
#
# Descriptive statistics for 1B3GDEL:
# count    7.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 1B3GDEL, dtype: float64
#
#
# Descriptive statistics for 1B6RXXX:
# count    27.000000
# mean      1.111111
# std       0.423659
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: 1B6RXXX, dtype: float64
#
#
# Descriptive statistics for 1B6GDEL:
# count    83.000000
# mean      1.120482
# std       0.327503
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 1B6GDEL, dtype: float64
#
#
# Descriptive statistics for 1B6GDEH:
# count    5.000000
# mean     1.200000
# std      0.447214
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      2.000000
# Name: 1B6GDEH, dtype: float64
#
#
# Descriptive statistics for 1D4CRXX:
# count    21.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 1D4CRXX, dtype: float64
#
#
# Descriptive statistics for 1D4GDEL:
# count    120.000000
# mean       1.141667
# std        0.395263
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: 1D4GDEL, dtype: float64
#
#
# Descriptive statistics for 1D4GDEH:
# count    19.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 1D4GDEH, dtype: float64
#
#
# Descriptive statistics for 1D4GDSH:
# count    13.000000
# mean      1.307692
# std       0.630425
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: 1D4GDSH, dtype: float64
#
#
# Descriptive statistics for 1D5RXXX:
# count    4.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 1D5RXXX, dtype: float64
#
#
# Descriptive statistics for 1D5GDEL:
# count    32.000000
# mean      1.250000
# std       0.622171
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       4.000000
# Name: 1D5GDEL, dtype: float64
#
#
# Descriptive statistics for 1F3RXXX:
# count    36.000000
# mean      1.555556
# std       1.731134
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       8.000000
# Name: 1F3RXXX, dtype: float64
#
#
# Descriptive statistics for 1F3GDEL:
# count    178.000000
# mean       1.477528
# std        1.105738
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        8.000000
# Name: 1F3GDEL, dtype: float64
#
#
# Descriptive statistics for 1F3GDEH:
# count    75.000000
# mean      1.186667
# std       0.651263
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       5.000000
# Name: 1F3GDEH, dtype: float64
#
#
# Descriptive statistics for 1F3GDSH:
# count    25.000000
# mean      1.240000
# std       0.723418
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       4.000000
# Name: 1F3GDSH, dtype: float64
#
#
# Descriptive statistics for 1H5ELXX:
# count    5.000000
# mean     1.200000
# std      0.447214
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      2.000000
# Name: 1H5ELXX, dtype: float64
#
#
# Descriptive statistics for 1H5GDEL:
# count    19.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 1H5GDEL, dtype: float64
#
#
# Descriptive statistics for 1H5GDSH:
# count    2.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 1H5GDSH, dtype: float64
#
#
# Descriptive statistics for 2A3ELXX:
# count    2.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 2A3ELXX, dtype: float64
#
#
# Descriptive statistics for 2A3RLXX:
# count    4.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 2A3RLXX, dtype: float64
#
#
# Descriptive statistics for 2A3GDXX:
# count    148.000000
# mean       1.202703
# std        0.521112
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: 2A3GDXX, dtype: float64
#
#
# Descriptive statistics for 2A3GDEL:
# count    80.00000
# mean      1.20000
# std       0.86273
# min       1.00000
# 25%       1.00000
# 50%       1.00000
# 75%       1.00000
# max       8.00000
# Name: 2A3GDEL, dtype: float64
#
#
# Descriptive statistics for 2A3GDEH:
# count    21.000000
# mean      1.285714
# std       0.462910
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000
# Name: 2A3GDEH, dtype: float64
#
#
# Descriptive statistics for 2A3GDSH:
# count    9.000000
# mean     1.333333
# std      0.707107
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      3.000000
# Name: 2A3GDSH, dtype: float64
#
#
# Descriptive statistics for 2A7GDEL:
# count    10.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 2A7GDEL, dtype: float64
#
#
# Descriptive statistics for 2A8GDXX:
# count    12.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 2A8GDXX, dtype: float64
#
#
# Descriptive statistics for 2B0GDXX:
# count    19.000000
# mean      1.052632
# std       0.229416
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 2B0GDXX, dtype: float64
#
#
# Descriptive statistics for 2B3GDXX:
# count    57.000000
# mean      1.105263
# std       0.362738
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: 2B3GDXX, dtype: float64
#
#
# Descriptive statistics for 2B3GDEL:
# count    44.000000
# mean      1.159091
# std       0.369989
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 2B3GDEL, dtype: float64
#
#
# Descriptive statistics for 2B3GDSH:
# count    17.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 2B3GDSH, dtype: float64
#
#
# Descriptive statistics for 2B6RXXX:
# count    8.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 2B6RXXX, dtype: float64
#
#
# Descriptive statistics for 2B6GDEL:
# count    7.000000
# mean     1.142857
# std      0.377964
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      2.000000
# Name: 2B6GDEL, dtype: float64
#
#
# Descriptive statistics for 2D4RXXX:
# count    9.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 2D4RXXX, dtype: float64
#
#
# Descriptive statistics for 2D4GDEL:
# count    26.000000
# mean      1.038462
# std       0.196116
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 2D4GDEL, dtype: float64
#
#
# Descriptive statistics for 2E0GDXX:
# count    48.000000
# mean      1.083333
# std       0.279310
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 2E0GDXX, dtype: float64
#
#
# Descriptive statistics for 2E0GDEL:
# count    59.000000
# mean      1.135593
# std       0.392060
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: 2E0GDEL, dtype: float64
#
#
# Descriptive statistics for 2E4GDXX:
# count    7.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 2E4GDXX, dtype: float64
#
#
# Descriptive statistics for 2E4GDEH:
# count    8.000000
# mean     1.125000
# std      0.353553
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      2.000000
# Name: 2E4GDEH, dtype: float64
#
#
# Descriptive statistics for 2E5GDEL:
# count    33.000000
# mean      1.151515
# std       0.364110
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 2E5GDEL, dtype: float64
#
#
# Descriptive statistics for 2E5EHLX:
# count    4.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 2E5EHLX, dtype: float64
#
#
# Descriptive statistics for 2F0GDXX:
# count    20.000000
# mean      1.100000
# std       0.307794
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 2F0GDXX, dtype: float64
#
#
# Descriptive statistics for 2F0GDEL:
# count    5.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 2F0GDEL, dtype: float64
#
#
# Descriptive statistics for 2G0CGXX:
# count    24.000000
# mean      1.041667
# std       0.204124
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 2G0CGXX, dtype: float64
#
#
# Descriptive statistics for 2H2GDXX (Inv):
# count    28.000000
# mean      1.107143
# std       0.416270
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: 2H2GDXX (Inv), dtype: float64
#
#
# Descriptive statistics for 2H2GDEL:
# count    4.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 2H2GDEL, dtype: float64
#
#
# Descriptive statistics for 2N5CRXX:
# count    11.000000
# mean      1.090909
# std       0.301511
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 2N5CRXX, dtype: float64
#
#
# Descriptive statistics for 2N5GDXX:
# count    11.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 2N5GDXX, dtype: float64
#
#
# Descriptive statistics for 2N5GDEL:
# count    12.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 2N5GDEL, dtype: float64
#
#
# Descriptive statistics for 2N5GDEL (Inv):
# count    4.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 2N5GDEL (Inv), dtype: float64
#
#
# Descriptive statistics for 2T5RRLX-XX:
# count    10.000000
# mean      1.100000
# std       0.316228
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 2T5RRLX-XX, dtype: float64
#
#
# Descriptive statistics for 2T5RRLX-GX:
# count    10.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 2T5RRLX-GX, dtype: float64
#
#
# Descriptive statistics for 2T5GDEL:
# count    52.000000
# mean      1.096154
# std       0.357530
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: 2T5GDEL, dtype: float64
#
#
# Descriptive statistics for 3X7NEXX:
# count    13.000000
# mean      1.076923
# std       0.277350
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 3X7NEXX, dtype: float64
#
#
# Descriptive statistics for 3X7GDEL:
# count    58.000000
# mean      1.172414
# std       0.464075
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: 3X7GDEL, dtype: float64
#
#
# Descriptive statistics for 3X9GDXX:
# count    1.0
# mean     1.0
# std      NaN
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3X9GDXX, dtype: float64
#
#
# Descriptive statistics for 3X9GDEL:
# count    6.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3X9GDEL, dtype: float64
#
#
# Descriptive statistics for 3A2GDXX:
# count    16.0000
# mean      1.0625
# std       0.2500
# min       1.0000
# 25%       1.0000
# 50%       1.0000
# 75%       1.0000
# max       2.0000
# Name: 3A2GDXX, dtype: float64
#
#
# Descriptive statistics for 3A2GDEL:
# count    9.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3A2GDEL, dtype: float64
#
#
# Descriptive statistics for 3A2GDEN:
# count    10.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 3A2GDEN, dtype: float64
#
#
# Descriptive statistics for 3A7NXXX:
# count    14.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 3A7NXXX, dtype: float64
#
#
# Descriptive statistics for 3A7GDXX:
# count    9.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3A7GDXX, dtype: float64
#
#
# Descriptive statistics for 3B0GDXX:
# count    6.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3B0GDXX, dtype: float64
#
#
# Descriptive statistics for 3B0GDXX (inv):
# count    7.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3B0GDXX (inv), dtype: float64
#
#
# Descriptive statistics for 3B0GDEL:
# count    13.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 3B0GDEL, dtype: float64
#
#
# Descriptive statistics for 3F5GDXX:
# count    7.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3F5GDXX, dtype: float64
#
#
# Descriptive statistics for 3F5GDSH:
# count    6.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3F5GDSH, dtype: float64
#
#
# Descriptive statistics for 3D8GDXX:
# count    4.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3D8GDXX, dtype: float64
#
#
# Descriptive statistics for 3D8GDEL:
# count    26.000000
# mean      1.038462
# std       0.196116
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 3D8GDEL, dtype: float64
#
#
# Descriptive statistics for 3D8GDEH-DD:
# count    22.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 3D8GDEH-DD, dtype: float64
#
#
# Descriptive statistics for 3D8GD-DD:
# count    5.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3D8GD-DD, dtype: float64
#
#
# Descriptive statistics for 3D8GDEL (inv):
# count    25.00
# mean      1.04
# std       0.20
# min       1.00
# 25%       1.00
# 50%       1.00
# 75%       1.00
# max       2.00
# Name: 3D8GDEL (inv), dtype: float64
#
#
# Descriptive statistics for 3D8GDSH:
# count    4.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3D8GDSH, dtype: float64
#
#
# Descriptive statistics for 3E8GDXX:
# count    3.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3E8GDXX, dtype: float64
#
#
# Descriptive statistics for 3J0RXXX:
# count    3.000000
# mean     1.333333
# std      0.577350
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.500000
# max      2.000000
# Name: 3J0RXXX, dtype: float64
#
#
# Descriptive statistics for 3J0GDEL:
# count    18.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 3J0GDEL, dtype: float64
#
#
# Descriptive statistics for 3J0GDEL DD:
# count    9.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 3J0GDEL DD, dtype: float64
#
#
# Descriptive statistics for 5F3GDEL:
# count    12.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 5F3GDEL, dtype: float64
#
#
# Descriptive statistics for 5F3GDEL-DD:
# count    9.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 5F3GDEL-DD, dtype: float64
#
#
# Descriptive statistics for Air Cooler:
# count    15.000000
# mean      1.133333
# std       0.351866
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: Air Cooler, dtype: float64
#
#
# Descriptive statistics for 18 A AC:
# count    15.000000
# mean      1.200000
# std       0.560612
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: 18 A AC, dtype: float64
#
#
# Descriptive statistics for 18 C AC:
# count    45.000000
# mean      1.266667
# std       0.719848
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       4.000000
# Name: 18 C AC, dtype: float64
#
#
# Descriptive statistics for 12 C AC:
# count    16.000000
# mean      1.187500
# std       0.403113
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: 12 C AC, dtype: float64
#
#
# Descriptive statistics for 24 B AC:
# count    7.000000
# mean     2.000000
# std      2.645751
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      8.000000
# Name: 24 B AC, dtype: float64
#
#
# Descriptive statistics for 24 C AC:
# count    11.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: 24 C AC, dtype: float64
#
#
# Descriptive statistics for 18 F AC:
# count    5.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 18 F AC, dtype: float64

# %%
# Making the dataset file.

dataset = "Date,Model,Quantity\n"
for index in salesData.index:
    for column in salesData.columns:
        if column != "Date" and column != "Amount":
            value = salesData[column][index]
            quantity = 0
            if not math.isnan(value):
                quantity = value
            dataset += salesData["Date"][index] + "," + column + "," + str(quantity) + "\n"

f = open("dataset/Project Dataset/sales_data.csv", "w")
f.write(dataset)
f.close()
